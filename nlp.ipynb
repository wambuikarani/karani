# %%
import nltk
from nltk.tokenize import PunktSentenceTokenizer

# %%
my_text ="This is an example text with multiple sentences. Here is another sentence. This one ends with us."

# %%
tokenizer=PunktSentenceTokenizer() 
sentences=tokenizer.tokenize(my_text)
sentences
# Out:
# ['This is an example text with multiple sentences.',
#  'Here is another sentence.',
#  'This one ends with us.']

# %%
for sentence in sentences:
    print(sentence)
# Out:
# This is an example text with multiple sentences.
# Here is another sentence.
# This one ends with us.

# %%
# NLP uses unstructured data
import requests   #This allows you to send HTTP requests in python
from  bs4 import BeautifulSoup #bs4 is a python libraray for pulling data out of HTML and XML files.
url="https://www.the-star.co.ke/news/2026-02-09-united-opposition-hits-back-at-ruto-over-insults"
page = requests.get(url)
soup= BeautifulSoup(page.content,"html.parser")
div= soup.findAll("div",class_="story")
# soup=BeautifulSoup(str(div))
text=soup.get_text()
print(text)
# Out:
# United Opposition hits back at Ruto over ‘insults’ and education crisis claimsnews counties business Healthopinion sports Siasasasa Climate ChangeIn-picturesvideoPodcastsADVERTISEMENTUnited Opposition hits back at Ruto over ‘insults’ and education crisis claimsThey vowed to use the ballot to hold the President accountableby JULIUS OTIENONews09 February 2026 - 09:00ADVERTISEMENTIn SummaryThe United Opposition has taken a swipe at President William Ruto, accusing him of routinely dismissing critics as “fools” and lacking empathy over the growing challenges facing learners.Opposition leaders, speaking during a church service at the Catholic Diocese of Nyahururu, Njabini Parish in Kinangop, Nyandarua County, on Sunday, faulted the President for what they termed as misleading directives.Audio By VocalizeOpposition leaders Rigathi Gachagua and Justin Muturi
# at the Catholic Diocese of Nyahururu in Nyandarua
# /HANDOUTThe United Opposition has taken aim at President William
# ...

# %%
from nltk.tokenize import sent_tokenize,word_tokenize
tokenized_sent= sent_tokenize(text)
tokenized_word=word_tokenize(text)

print(tokenized_sent)
print(tokenized_word)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[46], line 2
#       1 from nltk.tokenize import sent_tokenize,word_tokenize
# ----> 2 tokenized_sent= sent_tokenize(text)
#       3 tokenized_word=word_tokenize(text)
#       5 print(tokenized_sent)
#
# File /usr/lib/python3/dist-packages/nltk/tokenize/__init__.py:106, in sent_tokenize(text, language)
#      96 def sent_tokenize(text, language="english"):
#      97     """
#      98     Return a sentence-tokenized copy of *text*,
#      99     using NLTK's recommended sentence tokenizer
#    (...)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#     107     return tokenizer.tokenize(text)
#
# ...

# %%
nltk.download("punkt")
from nltk.tokenize import sent_tokenize,word_tokenize
tokenized_sent= sent_tokenize(text)
tokenized_word=word_tokenize(text)

print(tokenized_sent)
print(tokenized_word)
# Out:
# [nltk_data] Downloading package punkt to /home/user/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...

# %%
nltk.download("stopwords")
from nltk.corpus import stopwords
print(stopwords.fileids())

# get English stop words
mystopwords=set(stopwords.words('english'))
print(mystopwords)
# Out:
# [nltk_data] Downloading package stopwords to /home/user/nltk_data...
# ['albanian', 'arabic', 'azerbaijani', 'basque', 'belarusian', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'tamil', 'turkish', 'uzbek']
# ...

# %%
filtered_words=[]
for word in tokenized_word:
    if word.lower()not in  mystopwords:
        filtered_words.append(word)
print(f"old words:{tokenized_word}")
print(f"old words:{filtered_words}")
# Out:
# old words:['United', 'Opposition', 'hits', 'back', 'at', 'Ruto', 'over', '‘', 'insults', '’', 'and', 'education', 'crisis', 'claimsnews', 'counties', 'business', 'Healthopinion', 'sports', 'Siasasasa', 'Climate', 'ChangeIn-picturesvideoPodcastsADVERTISEMENTUnited', 'Opposition', 'hits', 'back', 'at', 'Ruto', 'over', '‘', 'insults', '’', 'and', 'education', 'crisis', 'claimsThey', 'vowed', 'to', 'use', 'the', 'ballot', 'to', 'hold', 'the', 'President', 'accountableby', 'JULIUS', 'OTIENONews09', 'February', '2026', '-', '09:00ADVERTISEMENTIn', 'SummaryThe', 'United', 'Opposition', 'has', 'taken', 'a', 'swipe', 'at', 'President', 'William', 'Ruto', ',', 'accusing', 'him', 'of', 'routinely', 'dismissing', 'critics', 'as', '“', 'fools', '”', 'and', 'lacking', 'empathy', 'over', 'the', 'growing', 'challenges', 'facing', 'learners.Opposition', 'leaders', ',', 'speaking', 'during', 'a', 'church', 'service', 'at', 'the', 'Catholic', 'Diocese', 'of', 'Nyahururu', ',', 'Njabini', 'Parish', 'in'
# ...
