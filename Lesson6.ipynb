# %%
import pandas as pd
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data=["Apple","Mango","banana","orange","pineapple","cherry","strawberry"]
fruits=pd.Series(data)
print(fruits)
# Out:
# 0         Apple
# 1         Mango
# 2        banana
# 3        orange
# 4     pineapple
# 5        cherry
# 6    strawberry
# dtype: object

# %%
students=[['Alex',17],['Mumbi',18],['Kimani',19],['Kabee',18]]
df=pd.DataFrame(students,columns=['name','age'])
df['age']=df['age'].astype(float)
print(df)
# Out:
#      name   age
# 0    Alex  17.0
# 1   Mumbi  18.0
# 2  Kimani  19.0
# 3   Kabee  18.0

# %%
pupils={
    'name':['John','Eve','Ethan','Linah','Kyle'],
    'age':[12,5,8,11,9]
}
pupilstable=pd.DataFrame(pupils,index=['1st','2nd','3rd','4th','5th'])
print(pupilstable)
# Out:
#       name  age
# 1st   John   12
# 2nd    Eve    5
# 3rd  Ethan    8
# 4th  Linah   11
# 5th   Kyle    9
